# %%
csdm_10_r2 = [0.974,0.984,0.972]
csdm_10_m = [1,0.99,0.97]
csdm_10_y = [-0.17,0,0.37]

csdm_03_r2 = [0.939,0.949,0.936]
csdm_03_m = [0.97,0.97,0.97]
csdm_03_y = [0.17,0.32,0.49]

csdm_01_r2 = [0.568,0.594,0.535]
csdm_01_m = [0.69,0.79,0.85]
csdm_01_y = [3.61,2.87,2.09]

csdm = [[csdm_10_r2,csdm_03_r2,csdm_01_r2],
        [csdm_10_m,csdm_03_m,csdm_01_m],
        [csdm_10_y,csdm_03_y,csdm_01_y]]

c_10_r2 = [0.984,0.985,0.981]
c_10_m = [1,0.99,0.98]
c_10_y = [-0.11,0.03,0.22]

c_03_r2 = [0.950,0.955,0.959]
c_03_m = [0.97,0.95,0.95]
c_03_y = [0.29,0.48,0.50]

c_01_r2 = [0.853,0.879,0.857]
c_01_m = [0.84,0.89,0.97]
c_01_y = [2.00,1.26,0.24]

c = [[c_10_r2,c_03_r2,c_01_r2],
        [c_10_m,c_03_m,c_01_m],
        [c_10_y,c_03_y,c_01_y]]

bsdm_10_r2 = [0.884,0.864,0.889]
bsdm_10_m = [0.97,0.95,0.97]
bsdm_10_y = [0.55,0.26,0.25]

bsdm_03_r2 = [0.806,0.682,0.717]
bsdm_03_m = [0.91,0.79,0.81]
bsdm_03_y = [0.55,1.95,2.11]

bsdm_01_r2 = [0.428,0.557,0.597]
bsdm_01_m = [0.5,0.71,0.96]
bsdm_01_y = [5.88,3.88,0.62]

bsdm = [[bsdm_10_r2,bsdm_03_r2,bsdm_01_r2],
        [bsdm_10_m,bsdm_03_m,bsdm_01_m],
        [bsdm_10_y,bsdm_03_y,bsdm_01_y]]

b_10_r2 = [0.872,0.897,0.915]
b_10_m = [0.96,0.97,0.95]
b_10_y = [0.09,0.03,0.58]

b_03_r2 = [0.858,0.862,0.888]
b_03_m = [0.96,0.93,0.91]
b_03_y = [0.15,0.54,0.97]

b_01_r2 = [0.720,0.747,0.859]
b_01_m = [0.75,0.78,0.94]
b_01_y = [2.88,2.5,0.59]

b = [[b_10_r2,b_03_r2,b_01_r2],
        [b_10_m,b_03_m,b_01_m],
        [b_10_y,b_03_y,b_01_y]]

# %%
from statistics import mean
from math import sqrt
print([mean(row) for row in bsdm[0]])
print([mean([sqrt(r2) for r2 in row]) for row in bsdm[0]])
# Out:
# [0.879, 0.735, 0.5273333333333333]
# [0.9375322367596953, 0.8567888218605676, 0.7243997221723103]

# %%
print([mean(row) for row in b[0]])
print([mean([sqrt(r2) for r2 in row]) for row in b[0]])
# Out:
# [0.8946666666666667, 0.8693333333333333, 0.7753333333333333]
# [0.9458221884279586, 0.9323533214595818, 0.8798807612452713]

# %%
print([mean(row) for row in csdm[0]])
print([mean([sqrt(r2) for r2 in row]) for row in csdm[0]])
# Out:
# [0.9766666666666667, 0.9413333333333334, 0.5656666666666667]
# [0.9882609094127682, 0.9702191212208272, 0.7519362146309895]

# %%
print([mean(row) for row in c[0]])
print([mean([sqrt(r2) for r2 in row]) for row in c[0]])
# Out:
# [0.9833333333333333, 0.9546666666666667, 0.863]
# [0.9916312815426969, 0.977068634184369, 0.9289576448902975]

# %%
from helpers import mpl_plotting_helpers as mph
from helpers import western_helpers as wh
import matplotlib.pyplot as plt
# Out:
# Loading the module: helpers.mpl_plotting_helpers
#
# Loading the module: helpers.general_helpers
#
# Loading the module: helpers.pandas_helpers
#
# Loading the module: helpers.stats_helpers.py
#
# numpy        1.19.2
# scipy         1.7.2
# pandas        1.2.3
#
# Loading the module: helpers.argcheck_helpers
#
# pandas        1.2.3
# numpy         1.19.2
#
# matplotlib    3.3.2
# numpy         1.19.2

# %%
comp_dict, test = wh.perform_statistics([["1.0 mg Control$+\Phi$SDM",csdm_10_r2],["1.0 mg Control",c_10_r2],
                                         ["1.0 mg BOOST$+\Phi$SDM",bsdm_10_r2],["1.0 mg BOOST",b_10_r2]],
                                                test = "Holm-Sidak",
                                                alpha = 0.05)
comp_dict = comp_dict.grab_results(test)
ax1,ax2 = mph.dotplot([["1.0 mg Control$+\Phi$SDM",csdm_10_r2],["1.0 mg Control",c_10_r2],
                                         ["1.0 mg BOOST$+\Phi$SDM",bsdm_10_r2],["1.0 mg BOOST",b_10_r2]],
                        comparisons = comp_dict,
                        filename = "r2_total_10.pdf",
                        colours = ["skyblue",
                                   "dodgerblue", "yellowgreen","green"],
                        xlabel = "1.0 mg",
                        ylabel = "Coefficient of Determination ($r^{2}$)",
                        title = "",
                        ymin = 0.4,
                        ymax = 1,
                        errorbar = "sd",
                    save_file = True)

ax2.legend(loc="lower left")

plt.show()

comp_dict, test = wh.perform_statistics([["0.3 mg Control$+\Phi$SDM",csdm_03_r2],["0.3 mg Control",c_03_r2],
                                         ["0.3 mg BOOST$+\Phi$SDM",bsdm_03_r2],["0.3 mg BOOST",b_03_r2]],
                                                test = "Holm-Sidak",
                                                alpha = 0.05)
comp_dict = comp_dict.grab_results(test)
ax1,ax2 = mph.dotplot([["0.3 mg Control$+\Phi$SDM",csdm_03_r2],["0.3 mg Control",c_03_r2],
            ["0.3 mg BOOST$+\Phi$SDM",bsdm_03_r2],["0.3 mg BOOST",b_03_r2]],
                        comparisons = comp_dict,
                        filename = "r2_total_03.pdf",
                        colours = ["skyblue",
                                   "dodgerblue", "yellowgreen","green"],
                        xlabel = "0.3 mg",
                        ylabel = "Coefficient of Determination ($r^{2}$)",
                        title = "",
                        ymin = 0.4,
                        ymax = 1,
                        errorbar = "sd",
                    save_file = True)

plt.show()

comp_dict, test = wh.perform_statistics([["0.1 mg Control$+\Phi$SDM",csdm_01_r2],["0.1 mg Control",c_01_r2],
                                         ["0.1 mg BOOST\n$+\Phi$SDM",bsdm_01_r2],["0.1 mg BOOST",b_01_r2]],
                                                test = "Holm-Sidak",
                                                alpha = 0.05)
comp_dict = comp_dict.grab_results(test)
mph.dotplot([["0.1 mg Control$+\Phi$SDM",csdm_01_r2],["0.1 mg Control",c_01_r2],
            ["0.1 mg BOOST\n$+\Phi$SDM",bsdm_01_r2],["0.1 mg BOOST",b_01_r2]],
                        comparisons = comp_dict,
                        filename = "r2_total_01.pdf",
                        colours = ["skyblue",
                                   "dodgerblue", "yellowgreen","green"],
                        xlabel = "0.1 mg",
                        ylabel = "Coefficient of Determination ($r^{2}$)",
                        title = "",
                        ymin = 0.4,
                        ymax = 1,
                        errorbar = "sd",
                    save_file = True)
plt.show()

# %%
comp_dict, test = wh.perform_statistics([["1.0 mg Control$+\Phi$SDM",csdm_10_m],["1.0 mg Control",c_10_m],
                                         ["1.0 mg BOOST$+\Phi$SDM",bsdm_10_m],["1.0 mg BOOST",b_10_m]],
                                                test = "Holm-Sidak",
                                                alpha = 0.05)
comp_dict = comp_dict.grab_results(test)
mph.dotplot([["1.0 mg Control$+\Phi$SDM",csdm_10_m],["1.0 mg Control",c_10_m],
             ["1.0 mg BOOST$+\Phi$SDM",bsdm_10_m],["1.0 mg BOOST",b_10_m]],
                        comparisons = comp_dict,
                        filename = "m_total_10.pdf",
                        colours = ["skyblue",
                                   "dodgerblue", "yellowgreen","green"],
                        xlabel = "",
                        ylabel = r"Regression Slope ($\beta_{1}$)",
                        title = "",
                        ymin = 0,
                        ymax = 1.1,
                        errorbar = "sd",
                    save_file = True)
plt.show()

comp_dict, test = wh.perform_statistics([["0.3 mg Control$+\Phi$SDM",csdm_03_m],["0.3 mg Control",c_03_m],
                                         ["0.3 mg BOOST$+\Phi$SDM",bsdm_03_m],["0.3 mg BOOST",b_03_m]],
                                                test = "Holm-Sidak",
                                                alpha = 0.05)
comp_dict = comp_dict.grab_results(test)
mph.dotplot([["0.3 mg Control$+\Phi$SDM",csdm_03_m],["0.3 mg Control",c_03_m],
            ["0.3 mg BOOST$+\Phi$SDM",bsdm_03_m],["0.3 mg BOOST",b_03_m]],
                        comparisons = comp_dict,
                        filename = "m_total_03.pdf",
                        colours = ["skyblue",
                                   "dodgerblue", "yellowgreen","green"],
                        xlabel = "",
                        ylabel = r"Regression Slope ($\beta_{1}$)",
                        title = "",
                        ymin = 0,
                        ymax = 1.1,
                        errorbar = "sd",
                    save_file = True)
plt.show()

comp_dict, test = wh.perform_statistics([["0.1 mg Control$+\Phi$SDM",csdm_01_m],["0.1 mg Control",c_01_m],
                                         ["0.1 mg BOOST$+\Phi$SDM",bsdm_01_m],["0.1 mg BOOST",b_01_m]],
                                                test = "Holm-Sidak",
                                                alpha = 0.05)
comp_dict = comp_dict.grab_results(test)
mph.dotplot([["0.1 mg Control$+\Phi$SDM",csdm_01_m],["0.1 mg Control",c_01_m],
            ["0.1 mg BOOST$+\Phi$SDM",bsdm_01_m],["0.1 mg BOOST",b_01_m]],
                        comparisons = comp_dict,
                        filename = "m_total_01.pdf",
                        colours = ["skyblue",
                                   "dodgerblue", "yellowgreen","green"],
                        xlabel = "",
                        ylabel = r"Regression Slope ($\beta_{1}$)",
                        title = "",
                        ymin = 0,
                        ymax = 1.1,
                        errorbar = "sd",
                    save_file = True)
plt.show()

# %%
comp_dict, test = wh.perform_statistics([["1.0 mg Control$+\Phi$SDM",csdm_10_y],["1.0 mg Control",c_10_y],
                                         ["1.0 mg BOOST$+\Phi$SDM",bsdm_10_y],["1.0 mg BOOST",b_10_y]],
                                                test = "Holm-Sidak",
                                                alpha = 0.05)
comp_dict = comp_dict.grab_results(test)
mph.dotplot([["1.0 mg Control$+\Phi$SDM",csdm_10_y],["1.0 mg Control",c_10_y],
             ["1.0 mg BOOST$+\Phi$SDM",bsdm_10_y],["1.0 mg BOOST",b_10_y]],
                        comparisons = comp_dict,
                        filename = "y_total_10.pdf",
                        colours = ["skyblue",
                                   "dodgerblue", "yellowgreen","green"],
                        xlabel = "",
                        ylabel = r"Regression Slope ($\beta_{0}$)",
                        title = "",
                        ymin = -1,
                        ymax = 6.5,
                        errorbar = "sd",
                    save_file = True)
plt.show()

comp_dict, test = wh.perform_statistics([["0.3 mg Control$+\Phi$SDM",csdm_03_y],["0.3 mg Control",c_03_y],
                                         ["0.3 mg BOOST$+\Phi$SDM",bsdm_03_y],["0.3 mg BOOST",b_03_y]],
                                                test = "Holm-Sidak",
                                                alpha = 0.05)
comp_dict = comp_dict.grab_results(test)
mph.dotplot([["0.3 mg Control$+\Phi$SDM",csdm_03_y],["0.3 mg Control",c_03_y],
            ["0.3 mg BOOST$+\Phi$SDM",bsdm_03_y],["0.3 mg BOOST",b_03_y]],
                        comparisons = comp_dict,
                        filename = "y_total_03.pdf",
                        colours = ["skyblue",
                                   "dodgerblue", "yellowgreen","green"],
                        xlabel = "",
                        ylabel = r"Regression Slope ($\beta_{0}$)",
                        title = "",
                        ymin = -1,
                        ymax = 6.5,
                        errorbar = "sd",
                    save_file = True)
plt.show()

comp_dict, test = wh.perform_statistics([["0.1 mg Control$+\Phi$SDM",csdm_01_y],["0.1 mg Control",c_01_y],
                                         ["0.1 mg BOOST$+\Phi$SDM",bsdm_01_y],["0.1 mg BOOST",b_01_y]],
                                                test = "Holm-Sidak",
                                                alpha = 0.05)
comp_dict = comp_dict.grab_results(test)
mph.dotplot([["0.1 mg Control$+\Phi$SDM",csdm_01_y],["0.1 mg Control",c_01_y],
            ["0.1 mg BOOST$+\Phi$SDM",bsdm_01_y],["0.1 mg BOOST",b_01_y]],
                        comparisons = comp_dict,
                        filename = "y_total_01.pdf",
                        colours = ["skyblue",
                                   "dodgerblue", "yellowgreen","green"],
                        xlabel = "",
                        ylabel = r"Regression Slope ($\beta_{0}$)",
                        title = "",
                        ymin = -1,
                        ymax = 6.5,
                        errorbar = "sd",
                    save_file = True)
plt.show()

# %%
filenames = ["figs/boost_vs_boostsdm_10mg_r2.pdf",
             "figs/control_vs_controlsdm_10mg_r2.pdf",
             "figs/boost_vs_boostsdm_03mg_r2.pdf",
             "figs/control_vs_controlsdm_03mg_r2.pdf",
             "figs/boost_vs_boostsdm_01mg_r2.pdf",
             "figs/control_vs_controlsdm_01mg_r2.pdf"]

pairs = [[["1.0 mg BOOST",b_10_r2],["1.0 mg BOOST$+\Phi$SDM",bsdm_10_r2]],
         [["1.0 mg Control",c_10_r2],["1.0 mg Control$+\Phi$SDM",csdm_10_r2]],
         [["0.3 mg BOOST",b_03_r2],["0.3 mg BOOST$+\Phi$SDM",bsdm_03_r2]],
         [["0.3 mg Control",c_03_r2],["0.3 mg Control$+\Phi$SDM", csdm_03_r2]],
         [["0.1 mg BOOST",b_01_r2],["0.1 mg BOOST$+\Phi$SDM",bsdm_01_r2]],
         [["0.1 mg Control",c_01_r2],["0.1 mg Control$+\Phi$SDM", csdm_01_r2]]]

colour = [["green", "yellowgreen"],
           ["dodgerblue", "skyblue"]]


for j in range(len(pairs)):
    comp_dict, test = wh.perform_statistics(pairs[j],
                                                test = "TTest",
                                                alpha = 0.05)
    comp_dict = comp_dict.grab_results(test)
    if j == 0:
        mph.dotplot(pairs[j],
                        comparisons = comp_dict,
                        filename = filenames[j],
                        colours = colour[j%2],
                        xlabel = "",
                        ylabel = "Coefficient of Determination ($r^{2}$)",
                        title = "",
                        ymin = 0,
                        ymax = 1,
                        errorbar = "sd",
                    save_file = True)
    elif j != len(pairs)-1:
         mph.dotplot(pairs[j],
                        comparisons = comp_dict,
                        filename = filenames[j],
                        colours = colour[j%2],
                        xlabel = "",
                        ylabel = "",
                        title = "",
                        ymin = 0,
                        ymax = 1,
                        errorbar = "sd",
                        remove_yaxis = True,
                    save_file = True)
    else:
        mph.dotplot(pairs[j],
                        comparisons = comp_dict,
           #             filename = filenames[j],
                        colours = colour[j%2],
                        xlabel = "",
                        ylabel = "",
                        title = "",
                        ymin = 0,
                        ymax = 1,
                        errorbar = "sd",
                        remove_yaxis = True)
plt.show()

# %%
filenames = ["figs/boost_vs_boostsdm_10mg_m.pdf",
             "figs/control_vs_controlsdm_10mg_m.pdf",
             "figs/boost_vs_boostsdm_03mg_m.pdf",
             "figs/control_vs_controlsdm_03mg_m.pdf",
             "figs/boost_vs_boostsdm_01mg_m.pdf",
             "figs/control_vs_controlsdm_01mg_m.pdf"]

pairs = [[["1.0 mg BOOST",b_10_m],["1.0 mg BOOST$+\Phi$SDM",bsdm_10_m]],
         [["1.0 mg Control",c_10_m],["1.0 mg Control$+\Phi$SDM",csdm_10_m]],
         [["1.0 mg BOOST",b_03_m],["1.0 mg BOOST$+\Phi$SDM",bsdm_03_m]],
         [["1.0 mg Control",c_03_m],["1.0 mg Control$+\Phi$SDM", csdm_03_m]],
         [["1.0 mg BOOST",b_01_m],["1.0 mg BOOST$+\Phi$SDM",bsdm_01_m]],
         [["1.0 mg Control",c_01_m],["1.0 mg Control$+\Phi$SDM", csdm_01_m]]]

colour = [["green", "yellowgreen"],
           ["dodgerblue", "skyblue"]]


for j in range(len(pairs)):
    comp_dict, test = wh.perform_statistics(pairs[j],
                                                test = "TTest",
                                                alpha = 0.05)
    comp_dict = comp_dict.grab_results(test)
    if j == 0:
        mph.dotplot(pairs[j],
                        comparisons = comp_dict,
                        filename = filenames[j],
                        colours = colour[j%2],
                        xlabel = "",
                        ylabel = r"Regression Slope ($\beta_{1}$)",
                        title = "",
                        ymin = 0,
                        ymax = 1.2,
                        errorbar = "sd",
                    save_file = True)
    elif j != len(pairs)-1:
         mph.dotplot(pairs[j],
                        comparisons = comp_dict,
                        filename = filenames[j],
                        colours = colour[j%2],
                        xlabel = "",
                        ylabel = "",
                        title = "",
                        ymin = 0,
                        ymax = 1.2,
                        errorbar = "sd",
                        remove_yaxis = True,
                    save_file = True)
    else:
        mph.dotplot(pairs[j],
                        comparisons = comp_dict,
           #             filename = filenames[j],
                        colours = colour[j%2],
                        xlabel = "",
                        ylabel = "",
                        title = "",
                        ymin = 0,
                        ymax = 1.2,
                        errorbar = "sd",
                        remove_yaxis = True)
plt.show()

# %%
filenames = ["figs/boost_vs_boostsdm_10mg_y.pdf",
             "figs/control_vs_controlsdm_10mg_y.pdf",
             "figs/boost_vs_boostsdm_03mg_y.pdf",
             "figs/control_vs_controlsdm_03mg_y.pdf",
             "figs/boost_vs_boostsdm_01mg_y.pdf",
             "figs/control_vs_controlsdm_01mg_y.pdf"]

pairs = [[["1.0 mg BOOST",b_10_y],["1.0 mg BOOST$+\Phi$SDM",bsdm_10_y]],
         [["1.0 mg Control",c_10_y],["1.0 mg Control$+\Phi$SDM",csdm_10_y]],
         [["1.0 mg BOOST",b_03_y],["1.0 mg BOOST$+\Phi$SDM",bsdm_03_y]],
         [["1.0 mg Control",c_03_y],["1.0 mg Control$+\Phi$SDM", csdm_03_y]],
         [["1.0 mg BOOST",b_01_y],["1.0 mg BOOST$+\Phi$SDM",bsdm_01_y]],
         [["1.0 mg Control",c_01_y],["1.0 mg Control$+\Phi$SDM", csdm_01_y]]]

colour = [["green", "yellowgreen"],
           ["dodgerblue", "skyblue"]]


for j in range(len(pairs)):
    comp_dict, test = wh.perform_statistics(pairs[j],
                                                test = "TTest",
                                                alpha = 0.05)
    comp_dict = comp_dict.grab_results(test)
    if j == 0:
        mph.dotplot(pairs[j],
                        comparisons = comp_dict,
                        filename = filenames[j],
                        colours = colour[j%2],
                        xlabel = "",
                        ylabel = r"Regression Intercept ($\beta_{0}$)",
                        title = "",
                        ymin = -1,
                        ymax = 6,
                        errorbar = "sd",
                    save_file = True)
    elif j != len(pairs)-1:
         mph.dotplot(pairs[j],
                        comparisons = comp_dict,
                        filename = filenames[j],
                        colours = colour[j%2],
                        xlabel = "",
                        ylabel = "",
                        title = "",
                        ymin = -1,
                        ymax = 6.5,
                        errorbar = "sd",
                        remove_yaxis = True,
                    save_file = True)
    else:
        mph.dotplot(pairs[j],
                        comparisons = comp_dict,
           #             filename = filenames[j],
                        colours = colour[j%2],
                        xlabel = "",
                        ylabel = "",
                        title = "",
                        ymin = -1,
                        ymax = 6,
                        errorbar = "sd",
                        remove_yaxis = True)
plt.show()
